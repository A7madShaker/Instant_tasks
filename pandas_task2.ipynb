# %%
import pandas as pd

# %%
#Task1: how to save 2 columns last 3 rows only

# %%
data=pd.read_csv("customer_shopping_data.csv")

# %%
data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
result = data[['gender', 'category']].tail(3)

# %%
result.to_csv('task2.csv', index=False)

# %%
data=pd.read_csv("task2.csv")

# %%
data
# Out:
#    gender         category
# 0    Male  Food & Beverage
# 1    Male       Technology
# 2  Female         Souvenir

# %%
#Task2:how to read random rows from data

# %%
data=pd.read_csv("customer_shopping_data.csv",header=2)

# %%
data
# Out:
#        I317333  C111565    Male  21            Shoes  3  1800.51   Debit Card  \
# 0      I127801  C266599    Male  20         Clothing  1   300.08         Cash
# 1      I173702  C988172  Female  66            Shoes  5  3000.85  Credit Card
# 2      I337046  C189076  Female  53            Books  4    60.60         Cash
# 3      I227836  C657758  Female  28         Clothing  5  1500.40  Credit Card
# 4      I121056  C151197  Female  49        Cosmetics  1    40.66         Cash
# ...        ...      ...     ...  ..              ... ..      ...          ...
# 99450  I219422  C441542  Female  45         Souvenir  5    58.65  Credit Card
# 99451  I325143  C569580    Male  27  Food & Beverage  2    10.46         Cash
# 99452  I824010  C103292    Male  63  Food & Beverage  2    10.46   Debit Card
# 99453  I702964  C800631    Male  56       Technology  4  4200.00         Cash
# 99454  I232867  C273973  Female  36         Souvenir  3    35.19  Credit Card
#
# ...

# %%
random_rows = data.sample(n=5)

# %%
random_rows
# Out:
#        I317333  C111565    Male  21      Shoes  3  1800.51   Debit Card  \
# 66471  I328987  C760929  Female  30  Cosmetics  4   162.64         Cash
# 91479  I259086  C907777  Female  56  Cosmetics  3   121.98  Credit Card
# 46038  I888801  C455306    Male  42   Souvenir  3    35.19   Debit Card
# 98201  I983697  C163324  Female  61      Books  4    60.60  Credit Card
# 71990  I186897  C168993    Male  55   Clothing  3   900.24         Cash
#
#        12/12/2021     Forum Istanbul
# 66471   10/6/2021       Zorlu Center
# 91479  16/03/2022  Emaar Square Mall
# 46038  25/03/2022       Istinye Park
# 98201  17/05/2021        Cevahir AVM
# 71990  14/01/2022          Metrocity
